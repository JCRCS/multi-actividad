# %%
import sys
sys.path.append(r"C:\JCRC\documentacion\Impala\Impala\aljibe_magico")

# %%
import paramiko
import pyodbc

# %%
from importlib import reload
import aljibe_magico
reload(aljibe_magico)
# Out:
# módulo aljibe_magico (versión 0.8.20190806) cargado!
# Un producto de la gloriosa  Direccion de Capacidades Analíticas.
# Use a su propio riesgo. Este producto no está garantizado ni soportado
#
# Ejecute: %shelp -- para ver funciones mágicas de Spark
# Ejecute: %ihelp -- para ver funciones mágicas de Impala
# <module 'aljibe_magico' from 'C:\\JCRC\\documentacion\\Impala\\Impala\\aljibe_magico\\aljibe_magico.py'>

# %%
import pandas as pd
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', -1)
# Out:
# c:\users\juacro\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# %connect_to_impala impala-prod proceso_enmascarado
# Out:
# Impala Mágica!
#
#           Un producto de la Gloriosa Dirección de Capacidades Analíticas.
#           Este producto no es soportado, ni mantenido regularmente.
#
#           ** Use a su propio riesgo**!
#
#           Documentación oficial de Impala:
#
#               https://www.cloudera.com/documentation/enterprise/5-12-x/topics/impala_datatypes.html
#
#           Manual del Aljibe de Datos:
#
#               http://vsc.bancolombia.corp/dircapacianalygobinf/caps/Documents/Modelo%20de%20Gobierno%20Landing%20Zone/Manual_Perdido_y_Encontrado_del_Aljibe_de_Datos_y_el_SAS_Grid.docx
#
#           Foro de usuarios del Aljibe de Datos:
#
#               http://vsc.bancolombia.corp/dircapacianalygobinf/caps/Lists/Foro%20de%20Usuarios%20del%20Aljibe%20de%20Datos%20y%20el%20SAS%20Grid/AllItems.aspx
#
#
# Conectados a Impala!
# Cambiándonos a db: proceso_enmascarado
# Ejecute: %ihelp para ayuda sobre las funciones disponibles.

# %%
# %ihelp
# Out:
# %connect_to_impala
#   %connect_to_impala <dsn-name>
#         Se conecta a Impala usando el nombre de una conexión ODBC
#         previamente configurada por el Administrador de conexiones ODBC
#
# %%isql
#
#     Función mágica. Sintaxis
#     %%isql [<n_rows>|no-fetch] [<df_name>]
#     <sql line1>
#     <sql line2>
#     ...
#
#     Ejecutar una única sentencia sql en Impala y opcionalmente retornar
#     el resultado como un dataframe de pandas.
#
#     El parámetro n_rows limita el número de filas que se transmiten
#     desde impala y se ponen en el dataframe.
#     Si no se especifica, se usa n_rows = 1000 por defecto.
#
#     El parámetro df_name es opcional. Este especifica el nombre (de la
#     variable global) que contendrá el dataframe resultante en el ambiente
#     de Python.
#
#     Si no se especifica df_name, se usará 'ires' por defecto.
#
#     Si se quiere especificar df_name, se debe especificar n_rows también.
#
# ...

# %% [markdown]
# # 1. Explorando bases de datos y sus tablas
# Comandos de exploración de bases de datos<br />
# show databases: Lista las bases de datos disponibles<br />
# use database: Cambiarse de base de datos<br />
# show tables in database: Lista las tablas disponibles en la base de datos especificada<br />
# show tables like 'wildcard_pattern':Lista las tablas disponibles en la bae de datos actual cuyo nombre cumple con el patrón especificado<br />
# describe table: Muestra un reporte con la lista de campos de la tabla y sus tipos de datos<br />
# show table stats table: Muestra las estadísticas de la tabla<br />
# show partitions table: Lista las particiones de la tabla<br />
# show files in table: Lista los archivos físicos que componene una tabla<br />

# %%
# %%isql
# SHOW DATABASES
# Out:
# query returned after 1.298 seconds.
# Result dataframe stored in global variable 'ires'
#                                name                comment
# 0   default                          Default Hive database
# 1   proceso_bam
# 2   proceso_bam_veg_cap_analitic
# 3   proceso_enmascarado
# 4   resultados
# 5   resultados_bam_veg_cap_analitic
# 6   s_bam_apoyo_corporativo
# 7   s_bam_apoyo_financiero
# 8   s_bam_canales
# 9   s_bam_clientes
# 10  s_bam_productos

# %%
# %%isql
# USE PROCESO_ENMASCARADO
# Out:
# conn.execute returned after 0.277 seconds.

# %%
# %%isql
# SHOW TABLES IN PROCESO_ENMASCARADO
# Out:
# query returned after 1.151 seconds.
# WARNING: only 1000 rows fetched
# Result dataframe stored in global variable 'ires'
#                              name
# 0     accounts_ingest
# 1     ad_temp_c
# 2     ad_temp_p
# 3     adq_abonos_apli_trx
# 4     adq_abonos_apli_trx_0
# ...                     ...
# 1124  vds_rela_comis
# 1125  vds_rela_comis_julio
# 1126  vds_relacion_completa_julio
# 1127  vds_relacion_julio
# 1128  vds_relacion_tarjeta
#
# [1129 rows x 1 columns]

# %%
len(ires)
# Out:
# 1129

# %%
for iTable in ires.name:
    print(f"%%isql \n DESCRIBE {iTable}")
# Out:
# %%isql
#  DESCRIBE accounts_ingest
# %%isql
#  DESCRIBE ad_temp_c
# %%isql
#  DESCRIBE ad_temp_p
# %%isql
#  DESCRIBE adq_abonos_apli_trx
# %%isql
#  DESCRIBE adq_abonos_apli_trx_0
# %%isql
#  DESCRIBE adq_abonos_apli_trx_1
# %%isql
#  DESCRIBE adq_abonos_apli_trx_2
# %%isql
#  DESCRIBE adq_abonos_apli_trx_3
# %%isql
#  DESCRIBE adq_abonos_apli_trx_4
# %%isql
#  DESCRIBE adq_abonos_aplicados
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcuent
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhad
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhat
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhfa
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhid
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhma
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhmp
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhmr
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhms
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhpc
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhpd
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhpm
# %%isql
# ...

# %%
# %%isql
#  DESCRIBE accounts_ingest
# %%isql
#  DESCRIBE ad_temp_c
# %%isql
#  DESCRIBE ad_temp_p
# %%isql
#  DESCRIBE adq_abonos_apli_trx
# %%isql
#  DESCRIBE adq_abonos_apli_trx_0
# %%isql
#  DESCRIBE adq_abonos_apli_trx_1
# %%isql
#  DESCRIBE adq_abonos_apli_trx_2
# %%isql
#  DESCRIBE adq_abonos_apli_trx_3
# %%isql
#  DESCRIBE adq_abonos_apli_trx_4
# %%isql
#  DESCRIBE adq_abonos_aplicados
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcuent
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhad
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhat
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhfa
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhid
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhma
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhmp
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhmr
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhms
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhpc
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhpd
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhpm
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhtc
# %%isql
#  DESCRIBE adq_adqlibramd_adqffcwhtr
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhad
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhat
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhfa
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhid
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhma
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhmp
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhmr
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhms
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhpc
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhpd
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhpm
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhtc
# %%isql
#  DESCRIBE adq_adqlibramd_adqffdwhtr
# %%isql
#  DESCRIBE adq_adqlibramd_adqffestab
# %%isql
#  DESCRIBE adq_ajustes_apli_trx
# %%isql
#  DESCRIBE ajdg_optima_foplibnor3_centro
# %%isql
#  DESCRIBE ajdg_optima_foplibnor3_contab
# %%isql
#  DESCRIBE ajdg_optima_foplibnor3_cuenta
# %%isql
#  DESCRIBE ajdg_optima_foplibnor3_movimi
# %%isql
#  DESCRIBE ajdg_optima_foplibnor3_tercer
# %%isql
#  DESCRIBE ajustes_amex
# %%isql
#  DESCRIBE ajustes_amex_a
# %%isql
#  DESCRIBE ajustes_consolidado
# %%isql
#  DESCRIBE ajustes_consolidado_f466
# %%isql
#  DESCRIBE ajustes_consolidado_sef
# %%isql
#  DESCRIBE ajustes_maestro
# %%isql
#  DESCRIBE ajustes_maestro_a
# %%isql
#  DESCRIBE ajustes_master
# %%isql
#  DESCRIBE ajustes_master_a
# %%isql
#  DESCRIBE ajustes_visa
# %%isql
#  DESCRIBE ajustes_visa_a
# %%isql
#  DESCRIBE alivios
# %%isql
#  DESCRIBE alivios_2
# %%isql
#  DESCRIBE alternativasleasing
# %%isql
#  DESCRIBE amr_apli_plan
# %%isql
#  DESCRIBE amr_cli_pam_mayo
# %%isql
#  DESCRIBE amr_cli_planta_comecial_mayo
# %%isql
#  DESCRIBE amr_consolidado_adq
# %%isql
#  DESCRIBE amr_enero_pam
# %%isql
#  DESCRIBE amr_enero_pam2
# %%isql
#  DESCRIBE amr_enero_prod
# %%isql
#  DESCRIBE amr_enero_prod_cont
# %%isql
#  DESCRIBE amr_febrero_prod
# %%isql
#  DESCRIBE amr_inv_pipe
# %%isql
#  DESCRIBE amr_mayo_prod
# %%isql
#  DESCRIBE amr_rrmm_empresas
# %%isql
#  DESCRIBE amr_rrmm_empresas_comp
# %%isql
#  DESCRIBE amr_rrmm_pyme_comp
# %%isql
#  DESCRIBE api_base_clientes_cart
# %%isql
#  DESCRIBE api_resultados_ig_monto
# %%isql
#  DESCRIBE apuntado_alivios_vs_base_maestra_ago6
# %%isql
#  DESCRIBE asesores
# %%isql
#  DESCRIBE banistmo_calificada_actual
# %%isql
#  DESCRIBE banistmo_calificada_actual_201910_202002
# %%isql
#  DESCRIBE banistmo_reentrenamiento_2020
# %%isql
#  DESCRIBE bankvision_hist_final
# %%isql
#  DESCRIBE bankvision_historico
# %%isql
#  DESCRIBE base_ajustes_f466
# %%isql
#  DESCRIBE base_ajustes_mapas
# %%isql
#  DESCRIBE base_codigos_lau
# %%isql
#  DESCRIBE base_comercios_activos_dwh
# %%isql
#  DESCRIBE base_consecutivo
# %%isql
#  DESCRIBE base_consecutivo_prueba
# %%isql
#  DESCRIBE base_contactabilidad
# %%isql
#  DESCRIBE base_d11_hob
# %%isql
#  DESCRIBE base_d12_spor
# %%isql
#  DESCRIBE base_d60_functi
# %%isql
#  DESCRIBE base_d61_lob
# %%isql
#  DESCRIBE base_leasing
# %%isql
#  DESCRIBE base_leasing_habit
# %%isql
#  DESCRIBE base_master_cli_trd
# %%isql
#  DESCRIBE base_pre_gestion_dummy
# %%isql
#  DESCRIBE bco_resultado_final_preliminar
# %%isql
#  DESCRIBE bd_accionistas_final
# %%isql
#  DESCRIBE bd_bvcffctlka_actualizacion
# %%isql
#  DESCRIBE bd_bvcffctlli_actualizacion
# %%isql
#  DESCRIBE bd_bvcffctlmn_actualizacion
# %%isql
#  DESCRIBE bd_bvcffctlpe_actualizacion
# %%isql
#  DESCRIBE bd_bvcffctlsb_actualizacion
# %%isql
#  DESCRIBE beneficiario_caribe
# %%isql
#  DESCRIBE beneficiario_corporativo
# %%isql
#  DESCRIBE beneficiario_sur
# %%isql
#  DESCRIBE bines_onus
# %%isql
#  DESCRIBE biom_muestra
# %%isql
#  DESCRIBE biom_ultmes
# %%isql
#  DESCRIBE bizagi_comercial_dummy
# %%isql
#  DESCRIBE bizagi_lac_dummy
# %%isql
#  DESCRIBE bl_mre_def_parametros_t_1914140695
# %%isql
#  DESCRIBE bl_relacion_t_1912269875
# %%isql
#  DESCRIBE bl_relacion_t_1912271356
# %%isql
#  DESCRIBE bpr_resultado_final
# %%isql
#  DESCRIBE brm1
# %%isql
#  DESCRIBE brm_contener
# %%isql
#  DESCRIBE brm_final
# %%isql
#  DESCRIBE brm_revolvente
# %%isql
#  DESCRIBE brm_total
# %%isql
#  DESCRIBE buro_indep_sineeff_consolidado_jagn
# %%isql
#  DESCRIBE bvc_bvclibramd_bvcffblqic
# %%isql
#  DESCRIBE bvclegados_bvclibramd_bvcffacdcl
# %%isql
#  DESCRIBE bvclegados_bvclibramd_bvcffblqin
# %%isql
#  DESCRIBE bvclegados_bvclibramd_bvcffctlka
# %%isql
#  DESCRIBE bvclegados_bvclibramd_bvcffctlli
# %%isql
#  DESCRIBE bvclegados_bvclibramd_bvcffctlmn
# %%isql
#  DESCRIBE bvclegados_bvclibramd_bvcffctlpe
# %%isql
#  DESCRIBE bvclegados_bvclibramd_bvcffctlsb
# %%isql
#  DESCRIBE bvclegados_visionr_cmark
# %%isql
#  DESCRIBE bvclegados_visionr_cname
# %%isql
#  DESCRIBE bvclegados_visionr_cxref
# %%isql
#  DESCRIBE bvclegados_visionr_xbknam
# %%isql
#  DESCRIBE bvnc_riesgos_cenie
# %%isql
#  DESCRIBE bzk_cli_tmp
# %%isql
#  DESCRIBE bzk_cli_tmpii
# %%isql
#  DESCRIBE bzk_schcol_d01_user
# %%isql
#  DESCRIBE bzk_schcol_d05_master_data
# %%isql
#  DESCRIBE bzk_schcol_d09_client
# %%isql
#  DESCRIBE bzk_schcol_d09_client_p
# %%isql
#  DESCRIBE bzk_schcol_d41_md_field
# %%isql
#  DESCRIBE bzk_schcol_d42_md_lang_val
# %%isql
#  DESCRIBE bzk_schcol_d50_share_holde
# %%isql
#  DESCRIBE bzk_schcol_d57_clt_cne_inf
# %%isql
#  DESCRIBE bzk_schcol_d66_clt_org_goo
# %%isql
#  DESCRIBE bzk_schcol_d67_clt_org_rse
# %%isql
#  DESCRIBE bzk_schcol_d68_clt_opt_frg
# %%isql
#  DESCRIBE bzk_schcol_d69_clt_frg_pds
# %%isql
#  DESCRIBE canales_lz
# %%isql
#  DESCRIBE capacitacion_spark_titanic
# %%isql
#  DESCRIBE cartera_calificada_historica
# %%isql
#  DESCRIBE cat_segmento_cli_temp
# %%isql
#  DESCRIBE catalogo_ciiu_lz
# %%isql
#  DESCRIBE catalogo_cod_pais_lz
# %%isql
#  DESCRIBE catalogo_descripciones_lz
# %%isql
#  DESCRIBE catalogo_tipo_doc_lz
# %%isql
#  DESCRIBE categorias_diners_p5
# %%isql
#  DESCRIBE categorias_maestro_p5
# %%isql
#  DESCRIBE categorias_mastercard_credito_p5
# %%isql
#  DESCRIBE categorias_mastercard_debito_p5
# %%isql
#  DESCRIBE categorias_mcca_cre
# %%isql
#  DESCRIBE categorias_mcca_deb
# %%isql
#  DESCRIBE categorias_mcca_mae
# %%isql
#  DESCRIBE categorias_mcca_p1m
# %%isql
#  DESCRIBE categorias_mcca_p1m_cre
# %%isql
#  DESCRIBE categorias_mcca_p1m_deb
# %%isql
#  DESCRIBE categorias_mcca_p1m_mae
# %%isql
#  DESCRIBE categorias_mcca_pm
# %%isql
#  DESCRIBE categorias_visa_credito_p3
# %%isql
#  DESCRIBE categorias_visa_credito_p5
# %%isql
#  DESCRIBE categorias_visa_debito_p3
# %%isql
#  DESCRIBE categorias_visa_debito_p5
# %%isql
#  DESCRIBE categorias_visa_electron_p3
# %%isql
#  DESCRIBE categorias_visa_electron_p5
# %%isql
#  DESCRIBE categoriasmaster
# %%isql
#  DESCRIBE categoriasmcca
# %%isql
#  DESCRIBE categoriasvisa
# %%isql
#  DESCRIBE ce_caracterizacion_pj
# %%isql
#  DESCRIBE ce_caracterizacion_pn
# %%isql
#  DESCRIBE cee_ff
# %%isql
#  DESCRIBE ceniegarc_consolidado
# %%isql
#  DESCRIBE ceniegarcjulio
# %%isql
#  DESCRIBE cifras_diaria
# %%isql
#  DESCRIBE cis_ms_inv_bloqueos_valores
# %%isql
#  DESCRIBE cis_ms_inv_clientes
# %%isql
#  DESCRIBE cis_ms_inv_clientes_potenciales
# %%isql
#  DESCRIBE cis_ms_inv_oc
# %%isql
#  DESCRIBE cis_ms_inv_prod_valores
# %%isql
#  DESCRIBE cis_ms_inv_productos_nal
# %%isql
#  DESCRIBE clasf_client_normalizacion
# %%isql
#  DESCRIBE clasf_pos_neg
# %%isql
#  DESCRIBE clasificacion_pj_tmp
# %%isql
#  DESCRIBE client_produc_normalizacion_enm_lz
# %%isql
#  DESCRIBE clientes_mdm_dhw
# %%isql
#  DESCRIBE cod_dane
# %%isql
#  DESCRIBE cod_op_mon_ext_bzk_cli
# %%isql
#  DESCRIBE cod_orig_bienes_bzk_cli
# %%isql
#  DESCRIBE cod_orig_recursos_bzk_cli
# %%isql
#  DESCRIBE cod_pais_row_number
# %%isql
#  DESCRIBE cods_master
# %%isql
#  DESCRIBE comercios_activos_dwh
# %%isql
#  DESCRIBE comex_expo
# %%isql
#  DESCRIBE comex_impo
# %%isql
#  DESCRIBE conciliar_estandar_clientes_t
# %%isql
#  DESCRIBE conciliar_estandar_diario
# %%isql
#  DESCRIBE conciliar_portal_clientes_t
# %%isql
#  DESCRIBE consolidado_dinners
# %%isql
#  DESCRIBE consolidado_master
# %%isql
#  DESCRIBE consolidado_visa
# %%isql
#  DESCRIBE conteo_campos
# %%isql
#  DESCRIBE conteo_campos_criticos
# %%isql
#  DESCRIBE conteo_marcas
# %%isql
#  DESCRIBE conteo_proceso_aliado
# %%isql
#  DESCRIBE control_calidad
# %%isql
#  DESCRIBE control_clasf_campos
# %%isql
#  DESCRIBE control_clasificacion_entidad
# %%isql
#  DESCRIBE control_count_limp_fuente
# %%isql
#  DESCRIBE control_count_mcd_pj
# %%isql
#  DESCRIBE control_count_mdm
# %%isql
#  DESCRIBE control_cruce_mcm_mdm
# %%isql
#  DESCRIBE control_cruce_mdm_fil_pj
# %%isql
#  DESCRIBE control_cruce_tbl_gestor
# %%isql
#  DESCRIBE control_cruce_tbl_intermedia
# %%isql
#  DESCRIBE control_cruce_tbls_marcacion
# %%isql
#  DESCRIBE control_eliminacion_dupli
# %%isql
#  DESCRIBE control_fuentes
# %%isql
#  DESCRIBE control_fuentes_normalizacion
# %%isql
#  DESCRIBE control_gestor_cl_id_persona_nor
# %%isql
#  DESCRIBE control_gestor_cl_persona_nor
# %%isql
#  DESCRIBE control_intermedia_clientes_nor
# %%isql
#  DESCRIBE control_marcacion_entidades_tmp
# %%isql
#  DESCRIBE control_mcd
# %%isql
#  DESCRIBE control_mcd_nor
# %%isql
#  DESCRIBE control_mcd_pj
# %%isql
#  DESCRIBE control_mdm
# %%isql
#  DESCRIBE control_mdm_dir_nor
# %%isql
#  DESCRIBE control_porcentaje_prioridad
# %%isql
#  DESCRIBE control_proc_nor_cli
# %%isql
#  DESCRIBE control_resumen_claf_entidad
# %%isql
#  DESCRIBE control_resumen_normalizacion
# %%isql
#  DESCRIBE control_resumen_normalizacion_ii
# %%isql
#  DESCRIBE control_tabla_final
# %%isql
#  DESCRIBE control_tbl_claf_ent_final
# %%isql
#  DESCRIBE copia_gestor_cl_id_persona
# %%isql
#  DESCRIBE copia_gestor_cl_persona
# %%isql
#  DESCRIBE copia_intermedia_clientes_tmp
# %%isql
#  DESCRIBE copia_mcd
# %%isql
#  DESCRIBE copia_mcd_nor_tmp
# %%isql
#  DESCRIBE copia_mcd_pj
# %%isql
#  DESCRIBE copia_mcd_tmp
# %%isql
#  DESCRIBE copia_mdm_dir_tmp
# %%isql
#  DESCRIBE copia_mdm_nor_tmp
# %%isql
#  DESCRIBE copia_mdm_tmp
# %%isql
#  DESCRIBE corchuelo_dummy
# %%isql
#  DESCRIBE cov_qmr
# %%isql
#  DESCRIBE cps_visionr_lmbal
# %%isql
#  DESCRIBE creacion_costos
# %%isql
#  DESCRIBE creco
# %%isql
#  DESCRIBE cruce_base_clientes
# %%isql
#  DESCRIBE cruce_base_clientes_2
# %%isql
#  DESCRIBE cruce_mc_mt
# %%isql
#  DESCRIBE cruce_mcd_mdm
# %%isql
#  DESCRIBE cu_activos_lz
# %%isql
#  DESCRIBE cuentas
# %%isql
#  DESCRIBE cuentas_contables_lz
# %%isql
#  DESCRIBE cuentas_por_excepcion
# %%isql
#  DESCRIBE cun_ce_central_externa
# %%isql
#  DESCRIBE cun_ce_contadores
# %%isql
#  DESCRIBE cun_ce_cuenta_aho_cte
# %%isql
#  DESCRIBE cun_ce_decision
# %%isql
#  DESCRIBE cun_ce_sector_financiero_solidario
# %%isql
#  DESCRIBE cun_ce_sector_real_comercio
# %%isql
#  DESCRIBE cun_ce_sector_real_servicio
# %%isql
#  DESCRIBE cun_ce_tarjeta_credito
# %%isql
#  DESCRIBE cun_ci_cartera_castigada
# %%isql
#  DESCRIBE cun_ci_cartera_total
# %%isql
#  DESCRIBE cun_ci_central_interna
# %%isql
#  DESCRIBE cun_ci_contadores
# %%isql
#  DESCRIBE cun_ci_cuenta_ahorros
# %%isql
#  DESCRIBE cun_ci_cuenta_corriente
# %%isql
#  DESCRIBE cun_ci_decision
# %%isql
#  DESCRIBE cun_ci_tarjeta_credito
# %%isql
#  DESCRIBE cun_precalculos_cliente
# %%isql
#  DESCRIBE cuotas_extra_base_elim_dup
# %%isql
#  DESCRIBE cuotas_extra_base_final_prueba
# %%isql
#  DESCRIBE cuotas_extra_base_tmp
# %%isql
#  DESCRIBE cuotas_extra_bd_casos_adj
# %%isql
#  DESCRIBE cuotas_extra_bd_ia
# %%isql
#  DESCRIBE cuotas_extra_bd_ia_1
# %%isql
#  DESCRIBE cuotas_extra_bd_pg_
# %%isql
#  DESCRIBE cuotas_extra_bd_preg_dep
# %%isql
#  DESCRIBE cuotas_extra_biz_com_
# %%isql
#  DESCRIBE cuotas_extra_biz_lac_
# %%isql
#  DESCRIBE cuotas_extra_calend_0
# %%isql
#  DESCRIBE cuotas_extra_calend_1
# %%isql
#  DESCRIBE cuotas_extra_calend_2
# %%isql
#  DESCRIBE cuotas_extra_calend_3
# %%isql
#  DESCRIBE cuotas_extra_calend_4
# %%isql
#  DESCRIBE cuotas_extra_calend_5
# %%isql
#  DESCRIBE cuotas_extra_calend_f
# %%isql
#  DESCRIBE cuotas_extra_calendario_
# %%isql
#  DESCRIBE cuotas_extra_casos_adj_
# %%isql
#  DESCRIBE cuotas_extra_causal_rechazo_
# %%isql
#  DESCRIBE cuotas_extra_cierre_casos_ce_2072020_2
# %%isql
#  DESCRIBE cuotas_extra_combdpg
# %%isql
#  DESCRIBE cuotas_extra_consolidado
# %%isql
#  DESCRIBE cuotas_extra_consolidado_tmp
# %%isql
#  DESCRIBE cuotas_extra_corch_
# %%isql
#  DESCRIBE cuotas_extra_corch_crdpg
# %%isql
#  DESCRIBE cuotas_extra_corch_nocrdpg
# %%isql
#  DESCRIBE cuotas_extra_homolog_corch
# %%isql
#  DESCRIBE cuotas_extra_lac0716900
# %%isql
#  DESCRIBE cuotas_extra_lacbdpg
# %%isql
#  DESCRIBE cuotas_extra_mantenim_bkv
# %%isql
#  DESCRIBE cuotas_extra_novedades_
# %%isql
#  DESCRIBE cuotas_extra_rechazos_ia
# %%isql
#  DESCRIBE cuotas_extra_retrofecha
# %%isql
#  DESCRIBE cuotas_extra_salida_ia_
# %%isql
#  DESCRIBE cuotas_extra_tipo_oblig_
# %%isql
#  DESCRIBE cuotas_extra_validacion2
# %%isql
#  DESCRIBE cuotas_extra_validacion3
# %%isql
#  DESCRIBE cuotas_extra_validacion4
# %%isql
#  DESCRIBE cuotas_extra_validacion5
# %%isql
#  DESCRIBE d00_mdm_datos_generales_tmp_gsic
# %%isql
#  DESCRIBE d00_mdm_datos_generales_trd_gsic
# %%isql
#  DESCRIBE d01_user_create_tmp
# %%isql
#  DESCRIBE d01_user_tmp_gsic
# %%isql
#  DESCRIBE d01_user_update_tmp
# %%isql
#  DESCRIBE d05_attitudeovergr
# %%isql
#  DESCRIBE d05_certificationstat
# %%isql
#  DESCRIBE d05_city
# %%isql
#  DESCRIBE d05_clientidtype
# %%isql
#  DESCRIBE d05_clientidtype_gsic
# %%isql
#  DESCRIBE d05_clientoperationsf
# %%isql
#  DESCRIBE d05_clientorigingo
# %%isql
#  DESCRIBE d05_clientoriginresou
# %%isql
#  DESCRIBE d05_clientstatus
# %%isql
#  DESCRIBE d05_clienttaxnatur
# %%isql
#  DESCRIBE d05_clienttype
# %%isql
#  DESCRIBE d05_contactpositio
# %%isql
#  DESCRIBE d05_contacttype
# %%isql
#  DESCRIBE d05_country
# %%isql
#  DESCRIBE d05_customertypolo
# %%isql
#  DESCRIBE d05_function
# %%isql
#  DESCRIBE d05_gender
# %%isql
#  DESCRIBE d05_hobbies
# %%isql
#  DESCRIBE d05_internalrating
# %%isql
#  DESCRIBE d05_justificationforc
# %%isql
#  DESCRIBE d05_justificationforl
# %%isql
#  DESCRIBE d05_justificationforn
# %%isql
#  DESCRIBE d05_lineofbusiness
# %%isql
#  DESCRIBE d05_managementbran
# %%isql
#  DESCRIBE d05_managementsofsect
# %%isql
#  DESCRIBE d05_master
# %%isql
#  DESCRIBE d05_master_tmp_gsic
# %%isql
#  DESCRIBE d05_province
# %%isql
#  DESCRIBE d05_relationshipstatu
# %%isql
#  DESCRIBE d05_riskcalificati
# %%isql
#  DESCRIBE d05_segment
# %%isql
#  DESCRIBE d05_shareholderidt
# %%isql
#  DESCRIBE d05_shareholderkin
# %%isql
#  DESCRIBE d05_socialstyle
# %%isql
#  DESCRIBE d05_sports
# %%isql
#  DESCRIBE d05_subsegment
# %%isql
#  DESCRIBE d05_title
# %%isql
#  DESCRIBE d05_typeofaddress
# %%isql
#  DESCRIBE d05_typeofclient
# %%isql
#  DESCRIBE d05_typeofcontact
# %%isql
#  DESCRIBE d05_unit
# %%isql
#  DESCRIBE d09_client_final_gsic
# %%isql
#  DESCRIBE d09_client_tmp_gsic
# %%isql
#  DESCRIBE d09_client_trd_gsic
# %%isql
#  DESCRIBE d09_client_trdii_gsic
# %%isql
#  DESCRIBE d09_client_trdiii_gsic
# %%isql
#  DESCRIBE d09_client_trdiiii_gsic
# %%isql
#  DESCRIBE d09_client_trdiiiii_gsic
# %%isql
#  DESCRIBE d10_contact_trd_gsic
# %%isql
#  DESCRIBE d10_contact_trdii_gsic
# %%isql
#  DESCRIBE d11_contact_hob_final_gsic
# %%isql
#  DESCRIBE d11_contact_hob_trd_gsic
# %%isql
#  DESCRIBE d12_contac_spor_trd_gsic
# %%isql
#  DESCRIBE d12_contact_spor_final_gsic
# %%isql
#  DESCRIBE d41_md_field_tmp_gsic
# %%isql
#  DESCRIBE d42_md_lang_vald_tmp_gsic
# %%isql
#  DESCRIBE d50_share_holde_tmp_gsic
# %%isql
#  DESCRIBE d50_share_holde_trd_gsic
# %%isql
#  DESCRIBE d55_client_lob_trd_gsic
# %%isql
#  DESCRIBE d57_clt_cne_inf
# %%isql
#  DESCRIBE d57_clt_cne_inf_tmp_gsic
# %%isql
#  DESCRIBE d59_client_cont_trd_gsic
# %%isql
#  DESCRIBE d60_cont_functi_final_gsic
# %%isql
#  DESCRIBE d60_cont_functi_trd_gsic
# %%isql
#  DESCRIBE d61_cont_lob_final_gsic
# %%isql
#  DESCRIBE d61_contact_lob_trd_gsic
# %%isql
#  DESCRIBE d66_clt_org_goo_tmp_gsic
# %%isql
#  DESCRIBE d67_clt_org_rse_tmp_gsic
# %%isql
#  DESCRIBE d68_clt_opt_frg_tmp_gsic
# %%isql
#  DESCRIBE dcc_base_maestra_alternativas
# %%isql
#  DESCRIBE demo_usuarios_activos_prd
# %%isql
#  DESCRIBE des_seg_estado_00
# %%isql
#  DESCRIBE desembolsos_pyme_lauracar
# %%isql
#  DESCRIBE domina1
# %%isql
#  DESCRIBE domina_contener
# %%isql
#  DESCRIBE domina_final
# %%isql
#  DESCRIBE domina_revolvente
# %%isql
#  DESCRIBE domina_total
# %%isql
#  DESCRIBE dpg_gestor_gestor_fd_cuenta_fiduc
# %%isql
#  DESCRIBE dpg_gestor_gestor_fd_fiducia
# %%isql
#  DESCRIBE dpg_gestor_gestor_tes_egrmodfpago
# %%isql
#  DESCRIBE dpg_gestor_gestor_tes_egrmodulos
# %%isql
#  DESCRIBE dpg_gestor_gestor_tes_egrmodulos2
# %%isql
#  DESCRIBE dpg_gestor_gestor_tes_ing_mod_fp
# %%isql
#  DESCRIBE dpg_gestor_gestor_tes_ing_mod_fp2
# %%isql
#  DESCRIBE dpg_gestor_gestor_tes_ingresos_modulos
# %%isql
#  DESCRIBE dpg_gestor_gestor_tes_tipos_egreso
# %%isql
#  DESCRIBE dpg_gestor_gestor_tes_tipos_ingreso
# %%isql
#  DESCRIBE dwh_props_c
# %%isql
#  DESCRIBE dwh_props_p
# %%isql
#  DESCRIBE dwh_refs_c
# %%isql
#  DESCRIBE dwh_refs_p
# %%isql
#  DESCRIBE eco_car_fasecolda_complementaria
# %%isql
#  DESCRIBE eco_hab_mov_master_table
# %%isql
#  DESCRIBE eco_hab_ofertas_actuales
# %%isql
#  DESCRIBE eco_hab_recomendacion_inmuebles
# %%isql
#  DESCRIBE eco_mov_auto_propietarios
# %%isql
#  DESCRIBE eco_mov_base_pronostico_modelalt2
# %%isql
#  DESCRIBE eco_mov_guia_carac_fijas_fasecolda
# %%isql
#  DESCRIBE eco_mov_pronostico_modelo_veh_new
# %%isql
#  DESCRIBE eco_mov_pronostico_price_modelo_alter
# %%isql
#  DESCRIBE eco_mov_recomendacion_car
# %%isql
#  DESCRIBE eco_mov_result_spark_cluster_veh
# %%isql
#  DESCRIBE eco_mov_tabla_homologacion
# %%isql
#  DESCRIBE ecosistema_corporativo
# %%isql
#  DESCRIBE emergia1
# %%isql
#  DESCRIBE emergia_contener
# %%isql
#  DESCRIBE emergia_final
# %%isql
#  DESCRIBE emergia_revolvente
# %%isql
#  DESCRIBE emergia_total
# %%isql
#  DESCRIBE estados_param
# %%isql
#  DESCRIBE fco_catalogo_moras
# %%isql
#  DESCRIBE fco_comportamiento_moras
# %%isql
#  DESCRIBE fco_contadores_mora_obligacion
# %%isql
#  DESCRIBE fco_master_customer_data_api
# %%isql
#  DESCRIBE fco_saldos_optima
# %%isql
#  DESCRIBE fee_table_tc
# %%isql
#  DESCRIBE festivos_colombia
# %%isql
#  DESCRIBE ff_ecomov_cat_mk_mov
# %%isql
#  DESCRIBE frc_base_itc
# %%isql
#  DESCRIBE frc_bd_experiencia_cons
# %%isql
#  DESCRIBE frc_bd_subsidios
# %%isql
#  DESCRIBE frc_clientes
# %%isql
#  DESCRIBE frc_info_clientes_detalle_x_mes
# %%isql
#  DESCRIBE frc_maestro_ctas
# %%isql
#  DESCRIBE frc_matriz_banco
# %%isql
#  DESCRIBE frc_param_trx_alm
# %%isql
#  DESCRIBE frc_param_trx_alm_t
# %%isql
#  DESCRIBE frc_retiros_alm_atm_cb
# %%isql
#  DESCRIBE function_bzk_cli
# %%isql
#  DESCRIBE function_bzk_clicuatro
# %%isql
#  DESCRIBE function_bzk_clidos
# %%isql
#  DESCRIBE function_bzk_clitres
# %%isql
#  DESCRIBE gac_ingest
# %%isql
#  DESCRIBE galeria_fija
# %%isql
#  DESCRIBE galeria_variable
# %%isql
#  DESCRIBE gam_ingest
# %%isql
#  DESCRIBE gcm_alternat
# %%isql
#  DESCRIBE gcm_definicion_alternativas
# %%isql
#  DESCRIBE gestion_doc_normalizacion_lz
# %%isql
#  DESCRIBE gestor_gestor_cl_id_persona
# %%isql
#  DESCRIBE gestor_gestor_cl_persona
# %%isql
#  DESCRIBE getpolesbyhour
# %%isql
#  DESCRIBE gmp_agr_estabilidad_bucket2
# %%isql
#  DESCRIBE gmp_agr_gasto_resumen_ifrs9
# %%isql
#  DESCRIBE gmp_agr_marca_gasto_ifrs9
# %%isql
#  DESCRIBE gmp_agr_resultado_final
# %%isql
#  DESCRIBE gmp_bam_gasto_resumen_ifrs9
# %%isql
#  DESCRIBE gmp_bam_marca_gasto_ifrs9
# %%isql
#  DESCRIBE gmp_bam_resultado_final
# %%isql
#  DESCRIBE gmp_ban_estabilidad_bucket2
# %%isql
#  DESCRIBE gmp_ban_gasto_resumen_ifrs9
# %%isql
#  DESCRIBE gmp_ban_marca_gasto_ifrs9
# %%isql
#  DESCRIBE gmp_ban_resultado_final
# %%isql
#  DESCRIBE gmp_bco_mes_b
# %%isql
#  DESCRIBE gmp_bpa_estabilidad_bucket2
# %%isql
#  DESCRIBE gmp_bpa_gasto_resumen_ifrs9
# %%isql
#  DESCRIBE gmp_bpa_marca_gasto_ifrs9
# %%isql
#  DESCRIBE gmp_bpa_resultado_final
# %%isql
#  DESCRIBE gmp_bpr_estabilidad_bucket2
# %%isql
#  DESCRIBE gmp_bpr_gasto_resumen_ifrs9
# %%isql
#  DESCRIBE gmp_bpr_marca_gasto_ifrs9
# %%isql
#  DESCRIBE gmp_brp_marca_gasto_ifrs9
# %%isql
#  DESCRIBE gmp_cay_estabilidad_bucket2
# %%isql
#  DESCRIBE gmp_cay_gasto_resumen_ifrs9
# %%isql
#  DESCRIBE gmp_cay_marca_gasto_ifrs9
# %%isql
#  DESCRIBE gmp_cay_resultado_final
# %%isql
#  DESCRIBE gmp_fin_marca_gasto_ifrs9
# %%isql
#  DESCRIBE gmp_fin_resultado_final
# %%isql
#  DESCRIBE gmp_lba_marca_gasto_ifrs9
# %%isql
#  DESCRIBE gmp_lba_resultado_final
# %%isql
#  DESCRIBE gmv1
# %%isql
#  DESCRIBE gmv_b
# %%isql
#  DESCRIBE gmv_brm
# %%isql
#  DESCRIBE gmv_contener
# %%isql
#  DESCRIBE gmv_d
# %%isql
#  DESCRIBE gmv_domina
# %%isql
#  DESCRIBE gmv_e
# %%isql
#  DESCRIBE gmv_emergia
# %%isql
#  DESCRIBE gmv_final
# %%isql
#  DESCRIBE gmv_revolvente
# %%isql
#  DESCRIBE gmv_total
# %%isql
#  DESCRIBE gsap_cat_valdefecto_mdwh
# %%isql
#  DESCRIBE gsap_log_m_dwh
# %%isql
#  DESCRIBE gsap_m_bines
# %%isql
#  DESCRIBE gsap_m_comercios
# %%isql
#  DESCRIBE gsap_m_comisiones
# %%isql
#  DESCRIBE gsap_m_cuentas
# %%isql
#  DESCRIBE gsap_m_detalle_abonos
# %%isql
#  DESCRIBE gsap_m_detalle_abonos_temp
# %%isql
#  DESCRIBE gsap_m_resumen_abonos
# %%isql
#  DESCRIBE gsap_m_resumen_abonos_temp
# %%isql
#  DESCRIBE gsap_m_transaccional
# %%isql
#  DESCRIBE gsap_m_transaccional_temp
# %%isql
#  DESCRIBE gscnf_fco_gestor
# %%isql
#  DESCRIBE gscnf_fco_gestor_egresos
# %%isql
#  DESCRIBE gscnf_fco_gestor_ingresos
# %%isql
#  DESCRIBE gscnf_fco_gestor_temp
# %%isql
#  DESCRIBE gscnf_fco_mov_contables
# %%isql
#  DESCRIBE gsic_bzk_control_crudo
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d01
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d05
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d05_5
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d07
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d08
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d09
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d10
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d106
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d107
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d11
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d12
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d40
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d41
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d42
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d43
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d50
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d52
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d55
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d57
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d59
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d60
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d61
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d66
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d67
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_d68
# %%isql
#  DESCRIBE gsic_bzk_control_crudo_mdm
# %%isql
#  DESCRIBE gsic_bzk_control_etapai_d09
# %%isql
#  DESCRIBE gsic_bzk_control_etapaii_d09
# %%isql
#  DESCRIBE gsic_bzk_control_insercion
# %%isql
#  DESCRIBE gsic_bzk_control_insert_accionistas
# %%isql
#  DESCRIBE gsic_bzk_control_insert_client
# %%isql
#  DESCRIBE gsic_bzk_control_insert_contactos
# %%isql
#  DESCRIBE gsic_bzk_control_insert_mjunta
# %%isql
#  DESCRIBE gsic_bzk_control_procesos
# %%isql
#  DESCRIBE gsic_bzk_control_resumen_d09
# %%isql
#  DESCRIBE gsic_bzk_control_resumen_d106
# %%isql
#  DESCRIBE gsic_bzk_control_resumen_d50
# %%isql
#  DESCRIBE gsic_bzk_control_resumen_d59
# %%isql
#  DESCRIBE gsic_bzk_control_salida_d09
# %%isql
#  DESCRIBE gsic_bzk_control_salida_d106
# %%isql
#  DESCRIBE gsic_bzk_control_salida_d50
# %%isql
#  DESCRIBE gsic_bzk_control_salida_d59
# %%isql
#  DESCRIBE gsic_bzk_control_tmp
# %%isql
#  DESCRIBE gsic_bzk_control_tmp_d09
# %%isql
#  DESCRIBE gsic_bzk_control_tmp_d106
# %%isql
#  DESCRIBE gsic_bzk_control_tmp_d50
# %%isql
#  DESCRIBE gsic_bzk_control_tmp_d59
# %%isql
#  DESCRIBE gsic_bzk_control_tmpii
# %%isql
#  DESCRIBE gsic_bzk_control_tmpiii
# %%isql
#  DESCRIBE gsic_bzk_control_tmpiiii
# %%isql
#  DESCRIBE gsic_bzk_control_tmpiiiii
# %%isql
#  DESCRIBE gsic_bzk_control_trd_d106
# %%isql
#  DESCRIBE gsic_bzk_control_trd_d50
# %%isql
#  DESCRIBE gsic_bzk_control_trd_d59
# %%isql
#  DESCRIBE gsic_bzk_control_trdii_d59
# %%isql
#  DESCRIBE hmologacion_ref
# %%isql
#  DESCRIBE homologacion_cod_tipo_doc_tmp
# %%isql
#  DESCRIBE homologacion_pais
# %%isql
#  DESCRIBE homologacion_pais_tmp
# %%isql
#  DESCRIBE homologacion_pais_tmp_1
# %%isql
#  DESCRIBE homologacionmp
# %%isql
#  DESCRIBE horas_distancia
# %%isql
#  DESCRIBE ic_ac_categorias_consumo
# %%isql
#  DESCRIBE ic_ac_categorias_consumo_hist
# %%isql
#  DESCRIBE ic_ac_demografia1
# %%isql
#  DESCRIBE ic_ac_demografia1_hist
# %%isql
#  DESCRIBE ic_ac_demografia2
# %%isql
#  DESCRIBE ic_ac_demografia2_hist
# %%isql
#  DESCRIBE ic_ac_mapa
# %%isql
#  DESCRIBE ic_ac_mapa_hist
# %%isql
#  DESCRIBE ic_ac_ranking_establecimientos
# %%isql
#  DESCRIBE ic_ac_ranking_establecimientos_hist
# %%isql
#  DESCRIBE ic_base_inmuebles_master
# %%isql
#  DESCRIBE ic_config_base_entrenamiento_sin_ohe
# %%isql
#  DESCRIBE ic_config_var_fijas
# %%isql
#  DESCRIBE ic_config_var_fijas_hist
# %%isql
#  DESCRIBE ic_inicial_proyectos
# %%isql
#  DESCRIBE ic_inicial_proyectos_hist
# %%isql
#  DESCRIBE ic_inicial_proyectos_inmuebles
# %%isql
#  DESCRIBE ic_inicial_proyectos_inmuebles_hist
# %%isql
#  DESCRIBE ic_inmuebles_geohash_1km
# %%isql
#  DESCRIBE ic_pc_cliente_t1
# %%isql
#  DESCRIBE ic_pc_cliente_t1_hist
# %%isql
#  DESCRIBE ic_pc_cliente_t2
# %%isql
#  DESCRIBE ic_pc_cliente_t2_hist
# %%isql
#  DESCRIBE ic_pc_cliente_t3
# %%isql
#  DESCRIBE ic_pc_cliente_t3_hist
# %%isql
#  DESCRIBE ic_pc_lugares_trx_clientes
# %%isql
#  DESCRIBE ic_pc_lugares_trx_clientes_hist
# %%isql
#  DESCRIBE ic_pc_proyecto
# %%isql
#  DESCRIBE ic_pc_proyecto_hist
# %%isql
#  DESCRIBE ic_pc_zonas_interes_inmueble
# %%isql
#  DESCRIBE ic_pc_zonas_interes_inmueble_hist
# %%isql
#  DESCRIBE ic_tvz_demografia_proyectos
# %%isql
#  DESCRIBE ic_tvz_demografia_proyectos_hist
# %%isql
#  DESCRIBE ic_tvz_info_mensual_proyectos
# %%isql
#  DESCRIBE ic_tvz_info_mensual_proyectos_hist
# %%isql
#  DESCRIBE ic_tvz_ventas_mensuales
# %%isql
#  DESCRIBE ic_tvz_ventas_mensuales_hist
# %%isql
#  DESCRIBE ic_tvz_vista_geohash
# %%isql
#  DESCRIBE ic_tvz_vista_geohash_hist
# %%isql
#  DESCRIBE inforec_tiempo
# %%isql
#  DESCRIBE ingestiones_lz
# %%isql
#  DESCRIBE intermedia_clientes
# %%isql
#  DESCRIBE inventario_fuentes_lz
# %%isql
#  DESCRIBE jpd_kaggle_test
# %%isql
#  DESCRIBE jpd_kaggle_train
# %%isql
#  DESCRIBE kudu_t1
# %%isql
#  DESCRIBE lam_ingest
# %%isql
#  DESCRIBE lauracar_clientespymehist
# %%isql
#  DESCRIBE lc_aws_consolidado_diario
# %%isql
#  DESCRIBE lc_aws_consolidado_mensual
# %%isql
#  DESCRIBE lc_aws_detalle_abono_credito
# %%isql
#  DESCRIBE lc_aws_mvtos_transaccionales
# %%isql
#  DESCRIBE lc_aws_topes_sug_categoria
# %%isql
#  DESCRIBE lc_aws_topes_sug_ingreso
# %%isql
#  DESCRIBE limpieza_fuente
# %%isql
#  DESCRIBE limpieza_fuenteeeee
# %%isql
#  DESCRIBE lob_bzk_cli
# %%isql
#  DESCRIBE lob_bzk_clidos
# %%isql
#  DESCRIBE lob_bzk_clitres
# %%isql
#  DESCRIBE logit_banco_pn_cc_mar20
# %%isql
#  DESCRIBE ltd_ingest
# %%isql
#  DESCRIBE ltdh_ingest
# %%isql
#  DESCRIBE m_abonos_tempi2_c
# %%isql
#  DESCRIBE m_abonos_tempi2_p
# %%isql
#  DESCRIBE m_abonos_tempi_c
# %%isql
#  DESCRIBE m_abonos_tempi_p
# %%isql
#  DESCRIBE m_comercios_c
# %%isql
#  DESCRIBE m_comercios_p
# %%isql
#  DESCRIBE m_comisiones_c
# %%isql
#  DESCRIBE m_comisiones_p
# %%isql
#  DESCRIBE m_cuentas_temp_c
# %%isql
#  DESCRIBE m_cuentas_temp_p
# %%isql
#  DESCRIBE m_det_abonos_tempi
# %%isql
#  DESCRIBE m_det_abonos_tempi_c
# %%isql
#  DESCRIBE m_trans_c
# %%isql
#  DESCRIBE m_trans_p
# %%isql
#  DESCRIBE mapas_t
# %%isql
#  DESCRIBE marcacion_clientes_extranjeros
# %%isql
#  DESCRIBE marcacion_entidad
# %%isql
#  DESCRIBE marcacion_entidad_p
# %%isql
#  DESCRIBE marcacion_entidades_p
# %%isql
#  DESCRIBE marcacion_entidades_tmp
# %%isql
#  DESCRIBE marcas_def_redif_tc
# %%isql
#  DESCRIBE marcas_def_redif_tc2
# %%isql
#  DESCRIBE master
# %%isql
#  DESCRIBE master_bzk_accionistas
# %%isql
#  DESCRIBE master_bzk_accionistas_prueba
# %%isql
#  DESCRIBE master_bzk_cli_tmp
# %%isql
#  DESCRIBE master_bzk_client
# %%isql
#  DESCRIBE master_bzk_client_prueba
# %%isql
#  DESCRIBE master_bzk_client_pruebita
# %%isql
#  DESCRIBE master_bzk_contact_tmp
# %%isql
#  DESCRIBE master_bzk_contact_tmp_a
# %%isql
#  DESCRIBE master_bzk_contactos
# %%isql
#  DESCRIBE master_bzk_contactos_prueba
# %%isql
#  DESCRIBE master_bzk_mjunta
# %%isql
#  DESCRIBE master_bzk_mjunta_prueba
# %%isql
#  DESCRIBE master_customer_data
# %%isql
#  DESCRIBE mater_customer_data_pj_tmp
# %%isql
#  DESCRIBE matriz_de_beneficios
# %%isql
#  DESCRIBE mcca_mcc
# %%isql
#  DESCRIBE mcd_copia_tmp
# %%isql
#  DESCRIBE mcm_copia_tmp
# %%isql
#  DESCRIBE mdm_datos_generales
# %%isql
#  DESCRIBE mdm_datos_generales_nor_tmp
# %%isql
#  DESCRIBE mdm_datos_generales_tmp
# %%isql
#  DESCRIBE mdm_datos_generales_tmp_1
# %%isql
#  DESCRIBE mdm_datos_generales_tmp_gsic
# %%isql
#  DESCRIBE mdm_direcciones
# %%isql
#  DESCRIBE mil_costos_trans_efe
# %%isql
#  DESCRIBE mil_efectivo_alerta_atipicos_t
# %%isql
#  DESCRIBE mil_efectivo_alerta_bandas_pronostico_t
# %%isql
#  DESCRIBE mil_efectivo_alerta_pedidos_t
# %%isql
#  DESCRIBE mil_efectivo_cupo_suc
# %%isql
#  DESCRIBE mil_evaluacion_modelo_pro
# %%isql
#  DESCRIBE mil_master_customer_data
# %%isql
#  DESCRIBE mil_modelos_seleccionados_pron_suc
# %%isql
#  DESCRIBE mil_monitoreo_efect
# %%isql
#  DESCRIBE mil_resultados_pronosticos_sucursales
# %%isql
#  DESCRIBE mil_saldo_suc_hist
# %%isql
#  DESCRIBE mil_transporte_efectivo_hist
# %%isql
#  DESCRIBE mora_cenie_feb
# %%isql
#  DESCRIBE mov_contab
# %%isql
#  DESCRIBE mov_contab_act
# %%isql
#  DESCRIBE mov_contab_ant
# %%isql
#  DESCRIBE movlog
# %%isql
#  DESCRIBE mre_bks_visionr_xgar
# %%isql
#  DESCRIBE mre_bks_visionr_xxgar
# %%isql
#  DESCRIBE mre_bvd_visionr_dbal
# %%isql
#  DESCRIBE mre_bvg_visionr_gldmon
# %%isql
#  DESCRIBE mre_cedex_respuesta
# %%isql
#  DESCRIBE mre_cedex_respuesta_tmp
# %%isql
#  DESCRIBE mre_cedex_respuesta_unicos
# %%isql
#  DESCRIBE mre_clientes_en_curso
# %%isql
#  DESCRIBE mre_cod_errores
# %%isql
#  DESCRIBE mre_cod_errores_tmp
# %%isql
#  DESCRIBE mre_conteos_rmas
# %%isql
#  DESCRIBE mre_conteos_salidas
# %%isql
#  DESCRIBE mre_cps_visionr_lmbal
# %%isql
#  DESCRIBE mre_dbal_ult_ingestion
# %%isql
#  DESCRIBE mre_def_parametros
# %%isql
#  DESCRIBE mre_def_parametros_i
# %%isql
#  DESCRIBE mre_def_parametros_test
# %%isql
#  DESCRIBE mre_def_parametros_test_1
# %%isql
#  DESCRIBE mre_def_parametros_test_2
# %%isql
#  DESCRIBE mre_gldmon_ult_ingestion
# %%isql
#  DESCRIBE mre_hist_rmas_prioridad
# %%isql
#  DESCRIBE mre_hist_rmas_prioridad_reporte
# %%isql
#  DESCRIBE mre_lmbal_ult_ingestion
# %%isql
#  DESCRIBE mre_master_customer_data
# %%isql
#  DESCRIBE mre_master_customer_data2
# %%isql
#  DESCRIBE mre_paraemtros_intregracion_cedex
# %%isql
#  DESCRIBE mre_parametros_prioriza
# %%isql
#  DESCRIBE mre_pic_visionr_xvprd
# %%isql
#  DESCRIBE mre_r_consolidado
# %%isql
#  DESCRIBE mre_reestructuraciones_masivas_hist_entrada
# %%isql
#  DESCRIBE mre_reestructuraciones_masivas_hist_entrada_act
# %%isql
#  DESCRIBE mre_reestructuraciones_masivas_hist_entrada_final
# %%isql
#  DESCRIBE mre_reestructuraciones_masivas_hist_preap_actuales
# %%isql
#  DESCRIBE mre_rmas_nuevos
# %%isql
#  DESCRIBE mre_rmas_resumen
# %%isql
#  DESCRIBE mre_salida_cedex
# %%isql
#  DESCRIBE mre_salida_cedex_unicos
# %%isql
#  DESCRIBE mre_salida_desafiliaciones
# %%isql
#  DESCRIBE mre_salida_fng
# %%isql
#  DESCRIBE mre_salida_lme
# %%isql
#  DESCRIBE mre_tdcffctasd
# %%isql
#  DESCRIBE mre_tdcffctasd_ult_ingestion
# %%isql
#  DESCRIBE mre_tdcffctasd_ult_ingestion_saldos
# %%isql
#  DESCRIBE mre_xgar_ult_ingestion
# %%isql
#  DESCRIBE mre_xvprd_ult_ingestion
# %%isql
#  DESCRIBE mre_xxgar_ult_ingestion
# %%isql
#  DESCRIBE mre_xxgar_xgar_ult
# %%isql
#  DESCRIBE ngcfd_centro
# %%isql
#  DESCRIBE ngcfd_congru
# %%isql
#  DESCRIBE ngcfd_contab
# %%isql
#  DESCRIBE ngcfd_cuenta
# %%isql
#  DESCRIBE ngcfd_movcom
# %%isql
#  DESCRIBE ngcfd_movimi
# %%isql
#  DESCRIBE ngcfd_tercer
# %%isql
#  DESCRIBE oblig
# %%isql
#  DESCRIBE obligaciones_alivios
# %%isql
#  DESCRIBE otrascategoriasmaster
# %%isql
#  DESCRIBE otros_calculos
# %%isql
#  DESCRIBE pagos_julio
# %%isql
#  DESCRIBE pagoseficiencia
# %%isql
#  DESCRIBE param_num_dias_venc
# %%isql
#  DESCRIBE pc_temp_c
# %%isql
#  DESCRIBE pc_temp_p
# %%isql
#  DESCRIBE pca_bizagi
# %%isql
#  DESCRIBE pca_bizagi_09
# %%isql
#  DESCRIBE pca_bizagi_10
# %%isql
#  DESCRIBE pca_bizagi_11
# %%isql
#  DESCRIBE pca_bizagi_12
# %%isql
#  DESCRIBE pca_bizagi_informe
# %%isql
#  DESCRIBE pca_clientes
# %%isql
#  DESCRIBE pca_consecutivo_m
# %%isql
#  DESCRIBE pca_consolidado
# %%isql
#  DESCRIBE pca_consolidado_1
# %%isql
#  DESCRIBE pca_consolidado_enriquecido
# %%isql
#  DESCRIBE pca_consolidado_enriquecido_final
# %%isql
#  DESCRIBE pca_consolidado_final
# %%isql
#  DESCRIBE pca_consolidado_mn
# %%isql
#  DESCRIBE pca_consolidado_mn_1
# %%isql
#  DESCRIBE pca_consolidado_mn_2
# %%isql
#  DESCRIBE pca_consolidado_mn_3
# %%isql
#  DESCRIBE pca_consolidado_mn_4
# %%isql
#  DESCRIBE pca_consolidado_mn_5
# %%isql
#  DESCRIBE pca_consolidado_mn_6
# %%isql
#  DESCRIBE pca_consolidado_mn_7
# %%isql
#  DESCRIBE pca_consolidado_mn_8
# %%isql
#  DESCRIBE pca_consolidado_mn_9
# %%isql
#  DESCRIBE pca_descarga_bizagi
# %%isql
#  DESCRIBE pca_detalle_autogestion
# %%isql
#  DESCRIBE pca_dias_habiles_prox_pago
# %%isql
#  DESCRIBE pca_dias_habiles_vto_final
# %%isql
#  DESCRIBE pca_docs
# %%isql
#  DESCRIBE pca_duplicados
# %%isql
#  DESCRIBE pca_duplicados_2
# %%isql
#  DESCRIBE pca_duplicados_3
# %%isql
#  DESCRIBE pca_duplicados_4
# %%isql
#  DESCRIBE pca_duplicados_err
# %%isql
#  DESCRIBE pca_estados
# %%isql
#  DESCRIBE pca_extrae_aprobados
# %%isql
#  DESCRIBE pca_fco_prestamo
# %%isql
#  DESCRIBE pca_festivos
# %%isql
#  DESCRIBE pca_garantias
# %%isql
#  DESCRIBE pca_hist_consolidado
# %%isql
#  DESCRIBE pca_hist_env_masivos
# %%isql
#  DESCRIBE pca_hist_lotes
# %%isql
#  DESCRIBE pca_hist_resp_masivos
# %%isql
#  DESCRIBE pca_hist_solicitudes
# %%isql
#  DESCRIBE pca_hist_solicitudes_corte
# %%isql
#  DESCRIBE pca_hist_solicitudes_envio
# %%isql
#  DESCRIBE pca_lmbal
# %%isql
#  DESCRIBE pca_lmbal_filt
# %%isql
#  DESCRIBE pca_lmbal_filt_p
# %%isql
#  DESCRIBE pca_lplan
# %%isql
#  DESCRIBE pca_param_amp_prox_pago
# %%isql
#  DESCRIBE pca_param_canal
# %%isql
#  DESCRIBE pca_param_cod_error
# %%isql
#  DESCRIBE pca_param_dias_habiles
# %%isql
#  DESCRIBE pca_param_docs
# %%isql
#  DESCRIBE pca_param_estado_docs
# %%isql
#  DESCRIBE pca_param_estado_prestamo
# %%isql
#  DESCRIBE pca_param_estados
# %%isql
#  DESCRIBE pca_param_estados_p
# %%isql
#  DESCRIBE pca_param_exfomento_mora
# %%isql
#  DESCRIBE pca_param_fomento_mora
# %%isql
#  DESCRIBE pca_param_fomento_prox_pago
# %%isql
#  DESCRIBE pca_param_frecuencia
# %%isql
#  DESCRIBE pca_param_ids
# %%isql
#  DESCRIBE pca_param_md
# %%isql
#  DESCRIBE pca_param_md_alivios
# %%isql
#  DESCRIBE pca_param_meses_canal
# %%isql
#  DESCRIBE pca_param_novedad_p
# %%isql
#  DESCRIBE pca_param_novedades
# %%isql
#  DESCRIBE pca_param_obl_dup_hist
# %%isql
#  DESCRIBE pca_param_obl_dup_lote
# %%isql
#  DESCRIBE pca_param_obligacion_preaprobado
# %%isql
#  DESCRIBE pca_param_obligacion_prestamos
# %%isql
#  DESCRIBE pca_param_pago_regular_excepcion
# %%isql
#  DESCRIBE pca_param_plan
# %%isql
#  DESCRIBE pca_param_prioridad
# %%isql
#  DESCRIBE pca_param_rev_docs
# %%isql
#  DESCRIBE pca_param_saldo_docs
# %%isql
#  DESCRIBE pca_param_tipo_prestamo
# %%isql
#  DESCRIBE pca_param_usado
# %%isql
#  DESCRIBE pca_param_vto_fag_fng
# %%isql
#  DESCRIBE pca_parametros_generales
# %%isql
#  DESCRIBE pca_planes_prorrogas
# %%isql
#  DESCRIBE pca_preaprobados
# %%isql
#  DESCRIBE pca_preaprobados_acum
# %%isql
#  DESCRIBE pca_prestamos
# %%isql
#  DESCRIBE pca_prev_salida_masivos
# %%isql
#  DESCRIBE pca_reg_acum
# %%isql
#  DESCRIBE pca_reg_indiv
# %%isql
#  DESCRIBE pca_respuesta_descargas
# %%isql
#  DESCRIBE pca_respuesta_finagro
# %%isql
#  DESCRIBE pca_respuesta_masivos
# %%isql
#  DESCRIBE pca_respuesta_tem_masivos
# %%isql
#  DESCRIBE pca_salida_bizagi
# %%isql
#  DESCRIBE pca_salida_fomento
# %%isql
#  DESCRIBE pca_tem_consolidado
# %%isql
#  DESCRIBE pca_xgar
# %%isql
#  DESCRIBE pca_xxgar
# %%isql
#  DESCRIBE perf_redif_tc
# %%isql
#  DESCRIBE planta_comercial_pgc
# %%isql
#  DESCRIBE pliegosfc_s201708
# %%isql
#  DESCRIBE pliegosfc_s201709
# %%isql
#  DESCRIBE pliegosfc_saldos_all
# %%isql
#  DESCRIBE pliegosfc_sicre_all_years_2
# %%isql
#  DESCRIBE pliegosfc_sicre_u2009
# %%isql
#  DESCRIBE pliegosfc_sicre_u2010
# %%isql
#  DESCRIBE pliegosfc_sicre_u2011
# %%isql
#  DESCRIBE pliegosfc_sicre_u2012
# %%isql
#  DESCRIBE pliegosfc_sicre_u2013
# %%isql
#  DESCRIBE pliegosfc_sicre_u2014
# %%isql
#  DESCRIBE pliegosfc_sicre_u2015
# %%isql
#  DESCRIBE pliegosfc_sicre_u2016
# %%isql
#  DESCRIBE pliegosfc_sicre_u2017
# %%isql
#  DESCRIBE preaprobados_santi
# %%isql
#  DESCRIBE preaprobados_santi1
# %%isql
#  DESCRIBE pred_clients_car_credit_mask
# %%isql
#  DESCRIBE pred_clients_data_mask
# %%isql
#  DESCRIBE pred_ctlg_vehiculos
# %%isql
#  DESCRIBE pred_estim_ingresos
# %%isql
#  DESCRIBE pred_kaggle_test_mask
# %%isql
#  DESCRIBE pred_kaggle_train_mask
# %%isql
#  DESCRIBE pred_relations_clients_mask
# %%isql
#  DESCRIBE pred_runt
# %%isql
#  DESCRIBE pred_transactions_1_year
# %%isql
#  DESCRIBE prefe
# %%isql
#  DESCRIBE preliminar_ceniegar_202008
# %%isql
#  DESCRIBE proceso_normalizacion_clientes
# %%isql
#  DESCRIBE productos_clientes_detallado_lauherre
# %%isql
#  DESCRIBE prox_mes_biom
# %%isql
#  DESCRIBE proy_score_banistmo_202009
# %%isql
#  DESCRIBE prueba_cabal
# %%isql
#  DESCRIBE prueba_gestor
# %%isql
#  DESCRIBE prueba_pca_lmbal_marca
# %%isql
#  DESCRIBE puntos_banco
# %%isql
#  DESCRIBE pvc_master_table_cluster_cumulative
# %%isql
#  DESCRIBE qflow_suc_distancia
# %%isql
#  DESCRIBE qr_pagos_sin_friccion
# %%isql
#  DESCRIBE r_mas_entrada_casteada
# %%isql
#  DESCRIBE r_mas_entrada_saldos
# %%isql
#  DESCRIBE r_mas_entrada_saldos_unicos
# %%isql
#  DESCRIBE r_mas_saldos_actualizados
# %%isql
#  DESCRIBE r_mas_saldos_actualizados_tmp
# %%isql
#  DESCRIBE r_mas_saldos_actualizados_tmp2
# %%isql
#  DESCRIBE r_mas_saldos_actualizados_tmp3
# %%isql
#  DESCRIBE r_mas_saldos_completos
# %%isql
#  DESCRIBE r_mas_saldos_completos_garantia
# %%isql
#  DESCRIBE r_mas_validacion_02
# %%isql
#  DESCRIBE r_mas_validacion_05
# %%isql
#  DESCRIBE r_mas_validacion_07
# %%isql
#  DESCRIBE r_mas_validacion_10
# %%isql
#  DESCRIBE r_mas_validacion_15
# %%isql
#  DESCRIBE r_mas_validacion_20
# %%isql
#  DESCRIBE r_mas_validacion_25
# %%isql
#  DESCRIBE r_mas_validacion_30
# %%isql
#  DESCRIBE r_mas_validacion_35
# %%isql
#  DESCRIBE r_mas_validacion_40
# %%isql
#  DESCRIBE rdcun_afpe_1
# %%isql
#  DESCRIBE rec_tpbi_movimientos
# %%isql
#  DESCRIBE rec_tpbi_movimientos_delta
# %%isql
#  DESCRIBE rec_tpbi_movimientos_delta_tmp_export
# %%isql
#  DESCRIBE rec_tpbi_movimientos_tmp_export
# %%isql
#  DESCRIBE reestructuraciones_masivas_hist
# %%isql
#  DESCRIBE reestructuraciones_masivas_hist_bk
# %%isql
#  DESCRIBE reestructuraciones_masivas_hist_lotes
# %%isql
#  DESCRIBE reestructuraciones_masivas_hist_lotes_bk
# %%isql
#  DESCRIBE reestructuraciones_masivas_r_hist
# %%isql
#  DESCRIBE reestructuraciones_masivas_r_hist_bk
# %%isql
#  DESCRIBE reestructuraciones_masivas_reporte
# %%isql
#  DESCRIBE reestructuraciones_masivas_rmas_reporte
# %%isql
#  DESCRIBE reestructuraciones_rmas_antiguos
# %%isql
#  DESCRIBE reestructuraciones_rmas_antiguos_desem
# %%isql
#  DESCRIBE reestructuraciones_rmas_ult_lote
# %%isql
#  DESCRIBE reestructuraciones_rmas_ult_lote2
# %%isql
#  DESCRIBE registros_fechas
# %%isql
#  DESCRIBE relacion
# %%isql
#  DESCRIBE rep_2230_mcc_mcca_cre
# %%isql
#  DESCRIBE rep_2230_mcc_mcca_deb
# %%isql
#  DESCRIBE rep_2230_mcc_mcca_mae
# %%isql
#  DESCRIBE reporte_2230_detallado3
# %%isql
#  DESCRIBE reporte_2230_detallado5
# %%isql
#  DESCRIBE reporte_2230_detallado_purchase
# %%isql
#  DESCRIBE reporte_2230_detallado_refund
# %%isql
#  DESCRIBE reporte_2230_mcc_diners_p5
# %%isql
#  DESCRIBE reporte_2230_mcc_maestro_p5
# %%isql
#  DESCRIBE reporte_2230_mcc_mastercard_credito_p5
# %%isql
#  DESCRIBE reporte_2230_mcc_mastercard_debito_p5
# %%isql
#  DESCRIBE reporte_2230_mcc_mcca_pm
# %%isql
#  DESCRIBE reporte_2230_mcc_visa_credito_p3
# %%isql
#  DESCRIBE reporte_2230_mcc_visa_credito_p5
# %%isql
#  DESCRIBE reporte_2230_mcc_visa_debito_p3
# %%isql
#  DESCRIBE reporte_2230_mcc_visa_debito_p5
# %%isql
#  DESCRIBE reporte_2230_mcc_visa_electron_p3
# %%isql
#  DESCRIBE reporte_2230_mcc_visa_electron_p5
# %%isql
#  DESCRIBE reporte_comercios_activos
# %%isql
#  DESCRIBE reporte_mapas
# %%isql
#  DESCRIBE res_davivienda_tc
# %%isql
#  DESCRIBE res_diners_tc
# %%isql
#  DESCRIBE res_electron_td
# %%isql
#  DESCRIBE res_maestro_td
# %%isql
#  DESCRIBE res_mastercard_tc
# %%isql
#  DESCRIBE res_mastercard_td
# %%isql
#  DESCRIBE res_visa_m_td
# %%isql
#  DESCRIBE res_visa_tc
# %%isql
#  DESCRIBE res_visa_td
# %%isql
#  DESCRIBE resul_fin_agr_0520
# %%isql
#  DESCRIBE resul_fin_bam_0520
# %%isql
#  DESCRIBE resul_fin_ban_0520
# %%isql
#  DESCRIBE resul_fin_bpa_0520
# %%isql
#  DESCRIBE resul_fin_bpr_0520
# %%isql
#  DESCRIBE resul_fin_bpr_05202
# %%isql
#  DESCRIBE resul_fin_cay_0520
# %%isql
#  DESCRIBE resul_fin_cay_05202
# %%isql
#  DESCRIBE resul_fin_lba_0520
# %%isql
#  DESCRIBE resultados_466
# %%isql
#  DESCRIBE resultados_466p
# %%isql
#  DESCRIBE row_functi_bzk
# %%isql
#  DESCRIBE row_hobby_bzk
# %%isql
#  DESCRIBE row_lob_bzk
# %%isql
#  DESCRIBE row_origen_bienes_bzk
# %%isql
#  DESCRIBE row_sport_bzk
# %%isql
#  DESCRIBE rth_ingest
# %%isql
#  DESCRIBE sab_def_redif_tc
# %%isql
#  DESCRIBE sab_def_redif_tc2
# %%isql
#  DESCRIBE saldo14
# %%isql
#  DESCRIBE saldo_dias
# %%isql
#  DESCRIBE saldo_inicial
# %%isql
#  DESCRIBE saldo_inicial_pre
# %%isql
#  DESCRIBE saldo_opt
# %%isql
#  DESCRIBE saldo_opt_act
# %%isql
#  DESCRIBE saldo_opt_ant
# %%isql
#  DESCRIBE saldo_pre_vert
# %%isql
#  DESCRIBE saldo_tr
# %%isql
#  DESCRIBE saldo_transp
# %%isql
#  DESCRIBE saldos20
# %%isql
#  DESCRIBE saldos22
# %%isql
#  DESCRIBE saldos_opt
# %%isql
#  DESCRIBE saldos_optima
# %%isql
#  DESCRIBE saldos_vert
# %%isql
#  DESCRIBE score_banistmo_202007
# %%isql
#  DESCRIBE score_banistmo_202007_prueba_simulacion
# %%isql
#  DESCRIBE scorepn_ak_calificacion
# %%isql
#  DESCRIBE scorepn_ak_calificacion_final
# %%isql
#  DESCRIBE sdias_horas_biom
# %%isql
#  DESCRIBE sebas_nits
# %%isql
#  DESCRIBE sharepoint
# %%isql
#  DESCRIBE sharepoint_fn
# %%isql
#  DESCRIBE sim_e2e_sabtblro
# %%isql
#  DESCRIBE sim_tab_desembolsos_enmascarado
# %%isql
#  DESCRIBE sim_tab_saldos_enmascarado
# %%isql
#  DESCRIBE sis_canal_sucursal
# %%isql
#  DESCRIBE sis_capaci_oficina
# %%isql
#  DESCRIBE sml_ach
# %%isql
#  DESCRIBE sml_ach_cru
# %%isql
#  DESCRIBE sml_atpt2
# %%isql
#  DESCRIBE sml_atpt22
# %%isql
#  DESCRIBE sml_cambio_cheq
# %%isql
#  DESCRIBE sml_cambio_cheq_cru
# %%isql
#  DESCRIBE sml_cheques_2020
# %%isql
#  DESCRIBE sml_cheques_2020_vf
# %%isql
#  DESCRIBE sml_cheques_caro
# %%isql
#  DESCRIBE sml_cheques_si
# %%isql
#  DESCRIBE sml_clientes_sin_rel
# %%isql
#  DESCRIBE sml_clientes_sin_rel_2
# %%isql
#  DESCRIBE sml_clientes_sin_rel_3
# %%isql
#  DESCRIBE sml_comisiones
# %%isql
#  DESCRIBE sml_comisiones_transpuesto
# %%isql
#  DESCRIBE sml_ig_tdc_sin_relacion
# %%isql
#  DESCRIBE sml_tcdffatpt1_cm
# %%isql
#  DESCRIBE sml_tdc_nits_sin_relacion
# %%isql
#  DESCRIBE sml_tdc_nomi
# %%isql
#  DESCRIBE sml_transacciones_diferidas_canceladas
# %%isql
#  DESCRIBE sml_transacciones_diferidas_canceladas_new
# %%isql
#  DESCRIBE stoc_personas_generales
# %%isql
#  DESCRIBE stoc_personas_preaprobados
# %%isql
#  DESCRIBE stoc_pyme_a_la_carta
# %%isql
#  DESCRIBE stoc_pyme_generales
# %%isql
#  DESCRIBE stoc_pyme_preaprobados_con_eeff
# %%isql
#  DESCRIBE stoc_pyme_preaprobados_sin_eeff
# %%isql
#  DESCRIBE suc_distancia1
# %%isql
#  DESCRIBE suc_distancia_base
# %%isql
#  DESCRIBE suc_distancia_base_from
# %%isql
#  DESCRIBE sucursales_biometria
# %%isql
#  DESCRIBE sum_amex_1
# %%isql
#  DESCRIBE sum_master_1
# %%isql
#  DESCRIBE sum_visa_1
# %%isql
#  DESCRIBE suma_positivos_negativos
# %%isql
#  DESCRIBE supernotariado
# %%isql
#  DESCRIBE tabla_clasificacion
# %%isql
#  DESCRIBE tabla_clasificacion_campos_tmp
# %%isql
#  DESCRIBE tabla_clasificacion_ciiu_tmp
# %%isql
#  DESCRIBE tabla_clasificacion_entidad
# %%isql
#  DESCRIBE tabla_congru
# %%isql
#  DESCRIBE tabla_control_consecutivos
# %%isql
#  DESCRIBE tabla_control_consecutivos_prueba
# %%isql
#  DESCRIBE tabla_detalle_comision
# %%isql
#  DESCRIBE tabla_detalle_p
# %%isql
#  DESCRIBE tabla_detalle_p2
# %%isql
#  DESCRIBE tabla_detalle_tii
# %%isql
#  DESCRIBE tabla_final_clas_entidades
# %%isql
#  DESCRIBE tabla_movcom
# %%isql
#  DESCRIBE tabla_movlog
# %%isql
#  DESCRIBE tablero_red
# %%isql
#  DESCRIBE tbl_acciones_tmp
# %%isql
#  DESCRIBE tbl_acciones_tmp_ii
# %%isql
#  DESCRIBE tbl_campo_fte_recursos
# %%isql
#  DESCRIBE tbl_campo_ingresos
# %%isql
#  DESCRIBE tbl_clasf_ent_porcen
# %%isql
#  DESCRIBE tbl_cli_normalizacion
# %%isql
#  DESCRIBE tbl_control_calidad
# %%isql
#  DESCRIBE tbl_cruce_gestor_tmp
# %%isql
#  DESCRIBE tbl_descrip_campos
# %%isql
#  DESCRIBE tbl_gestion_documental
# %%isql
#  DESCRIBE tbl_gestor_tmp
# %%isql
#  DESCRIBE tbl_row_number_gestor_tmp
# %%isql
#  DESCRIBE tbl_separacion_pais_tmp
# %%isql
#  DESCRIBE tbl_tmp_ent_finan
# %%isql
#  DESCRIBE tbl_unificacion_acciones
# %%isql
#  DESCRIBE tbl_union_
# %%isql
#  DESCRIBE tbl_union_ent_bancolombia
# %%isql
#  DESCRIBE tdc_tdclibramd_tdcffdmed1
# %%isql
#  DESCRIBE test_2
# %%isql
#  DESCRIBE test_coincidencia_ii
# %%isql
#  DESCRIBE test_coincidencia_pais
# %%isql
#  DESCRIBE tipo_venta_com_acti_dwh
# %%isql
#  DESCRIBE titularizadas
# %%isql
#  DESCRIBE tmp_encuesta_alivios_covid19_personas
# %%isql
#  DESCRIBE tmp_encuesta_alivios_covid19_personas_0814
# %%isql
#  DESCRIBE tmp_encuesta_alivios_covid19_personas_all
# %%isql
#  DESCRIBE trazabilidad_validacion
# %%isql
#  DESCRIBE trx_control_dual
# %%isql
#  DESCRIBE trx_segm_2020
# %%isql
#  DESCRIBE tvc_pagos_julio
# %%isql
#  DESCRIBE unfi_pais_mdm
# %%isql
#  DESCRIBE union_campos
# %%isql
#  DESCRIBE union_campos_ii
# %%isql
#  DESCRIBE union_campos_iii
# %%isql
#  DESCRIBE union_cont_rev
# %%isql
#  DESCRIBE union_cont_rev2
# %%isql
#  DESCRIBE union_productos_tarjetas
# %%isql
#  DESCRIBE union_productos_tarjetas_tmp
# %%isql
#  DESCRIBE union_tabla_clasf_campos
# %%isql
#  DESCRIBE validadcion_cartera_tex
# %%isql
#  DESCRIBE validadcion_cartera_tex_2
# %%isql
#  DESCRIBE vds_cuotas_manejo
# %%isql
#  DESCRIBE vds_descrip_fee_table
# %%isql
#  DESCRIBE vds_estado_fee_table
# %%isql
#  DESCRIBE vds_rela_comis
# %%isql
#  DESCRIBE vds_rela_comis_julio
# %%isql
#  DESCRIBE vds_relacion_completa_julio
# %%isql
#  DESCRIBE vds_relacion_julio
# %%isql
#  DESCRIBE vds_relacion_tarjeta
# Out:
# [42000] [Cloudera][ImpalaODBC] (360) Syntax error occurred during query execution: [HY000] : AnalysisException: Syntax error in line 2:
# %%isql
# ^
# Encountered: %
# Expected
#
# CAUSED BY: Exception: Syntax error
#  (360) (SQLExecDirectW)

# %%
ires.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-2dd29e87735f> in <module>
# ----> 1 ires.columns()
#
# TypeError: 'Index' object is not callable

# %%
type(ires)
# Out:
# pandas.core.frame.DataFrame

# %%
ires.name
# Out:
# 0       accounts_ingest
# 1       ad_temp_c
# 2       ad_temp_p
# 3       adq_abonos_apli_trx
# 4       adq_abonos_apli_trx_0
#                 ...
# 1124    vds_rela_comis
# 1125    vds_rela_comis_julio
# 1126    vds_relacion_completa_julio
# 1127    vds_relacion_julio
# 1128    vds_relacion_tarjeta
# Name: name, Length: 1129, dtype: object

# %%
# %%isql
# DESCRIBE comex_impo
# Out:
# query returned after 0.516 seconds.
# Result dataframe stored in global variable 'ires'
#                   name           type comment
# 0   ingestion_year      int
# 1   ingestion_month     tinyint
# 2   ingestion_day       tinyint
# 3   fec                 timestamp
# 4   anio                bigint
# 5   mes                 bigint
# 6   kaggle_id           bigint
# 7   ciudad              varchar(100)
# 8   descri_posicion     varchar(255)
# 9   aduana              varchar(50)
# 10  id_sia              varchar(15)
# 11  sia                 varchar(60)
# 12  via                 varchar(15)
# 13  transporte          varchar(60)
# 14  pais_procedencia    varchar(40)
# 15  pais_orig           varchar(40)
# 16  pais_compra         varchar(40)
# 17  id_aduana           bigint
# 18  dpto_orig           bigint
# 19  cnt                 double
# 20  unidad              varchar(30)
# 21  ciiu                varchar(100)
# 22  cuode               varchar(100)
# ...

# %%
ires
# Out:
#                   name           type comment
# 0   ingestion_year      int
# 1   ingestion_month     tinyint
# 2   ingestion_day       tinyint
# 3   fec                 timestamp
# 4   anio                bigint
# 5   mes                 bigint
# 6   kaggle_id           bigint
# 7   ciudad              varchar(100)
# 8   descri_posicion     varchar(255)
# 9   aduana              varchar(50)
# 10  id_sia              varchar(15)
# 11  sia                 varchar(60)
# 12  via                 varchar(15)
# 13  transporte          varchar(60)
# 14  pais_procedencia    varchar(40)
# 15  pais_orig           varchar(40)
# 16  pais_compra         varchar(40)
# 17  id_aduana           bigint
# 18  dpto_orig           bigint
# 19  cnt                 double
# 20  unidad              varchar(30)
# 21  ciiu                varchar(100)
# 22  cuode               varchar(100)
# 23  vlr_fob_uni         double
# 24  vlr_fob             double
# 25  vlr_cif             double
# ...

# %%
SHOW TABLES IN PROCESO_ENMAS
